# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
import base64
import requests

# %%
# keep this in a safe place.
from templates.apikey import apikey_token

# %% [markdown]
# ## Seasonal Team Stats

# %%
url='https://api.mysportsfeeds.com/v2.0/pull/mlb/2018-regular/team_stats_totals.json'

# %%
def get_request():
    # Request

    try:
        response = requests.get(            
            url=url,
            params={
                "team": "BOS",    
                "stats": 'AB',
            },
            headers={
                "Authorization": "Basic " + base64.b64encode('{}:{}'.format(apikey_token,'MYSPORTSFEEDS').encode('utf-8')).decode('ascii')
            }
        )
        return response.json()
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
response=get_request()
response
# Out:
# {'lastUpdatedOn': '2019-01-21T01:03:23.559Z',
#  'teamStatsTotals': [{'team': {'id': 113,
#     'city': 'Boston',
#     'name': 'Red Sox',
#     'abbreviation': 'BOS',
#     'homeVenue': {'id': 114, 'name': 'Fenway Park'},
#     'teamColoursHex': [],
#     'socialMediaAccounts': [],
#     'officialLogoImageSrc': None},
#    'stats': {'gamesPlayed': 162, 'batting': {'atBats': 5576}}}],
#  'references': {'teamStatReferences': [{'category': 'Batting',
#     'fullName': 'atBats',
#     'description': 'At Bats',
#     'abbreviation': 'AB',
#     'type': 'INTEGER'}]}}

# %%
response['teamStatsTotals'][0]['team']['city']
# Out:
# 'Boston'

# %%
response['teamStatsTotals'][0]['team']['name']
# Out:
# 'Red Sox'

# %%
response['teamStatsTotals'][0]['team']['homeVenue']['name']
# Out:
# 'Fenway Park'

# %%
response['teamStatsTotals'][0]['stats'].keys()
# Out:
# dict_keys(['gamesPlayed', 'batting'])

# %%
response['teamStatsTotals'][0]['stats']['batting'].keys()
# Out:
# dict_keys(['atBats'])

# %%
def whatsmywinpct(teamname):

    try:
        response = requests.get(            
            url=url,
            params={
                "team": teamname,                
            },
            headers={
                "Authorization": "Basic " + base64.b64encode('{}:{}'.format(apikey_token,'MYSPORTSFEEDS').encode('utf-8')).decode('ascii')
            }
        )
        r = response.json()
        return r['teamStatsTotals'][0]['stats']['standings']['winPct']
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
whatsmywinpct('BOS')
# Out:
# 0.667

# %%
whatsmywinpct('WAS')
# Out:
# 0.506

# %%
whatsmywinpct('NYM')
# Out:
# 0.475

# %% [markdown]
# ## Current Season (for list of stats)

# %%
url='https://api.mysportsfeeds.com/v2.0/pull/mlb/current_season.json?date=20190501'

# %%
def get_request():
    # Request

    try:
        response = requests.get(            
            url=url,
            params={
                  
            },
            headers={
                "Authorization": "Basic " + base64.b64encode('{}:{}'.format(apikey_token,'MYSPORTSFEEDS').encode('utf-8')).decode('ascii')
            }
        )
        return response.json()
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
get_request()
# Out:
# {'lastUpdatedOn': '2019-01-28T15:19:14.031Z',
#  'seasons': [{'name': '2019 Regular',
#    'slug': '2019-regular',
#    'startDate': '2019-03-20Z',
#    'endDate': '2019-09-29Z',
#    'seasonInterval': 'REGULAR',
#    'supportedTeamStats': [{'category': 'Batting',
#      'fullName': 'atBats',
#      'description': 'At Bats',
#      'abbreviation': 'AB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'runs',
#      'description': 'Runs',
#      'abbreviation': 'R',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'hits',
#      'description': 'Hits',
#      'abbreviation': 'H',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'secondBaseHits',
#      'description': '2nd Base Hits',
#      'abbreviation': '2B',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'thirdBaseHits',
#      'description': '3rd Base Hits',
#      'abbreviation': '3B',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'homeruns',
#      'description': 'Homeruns',
#      'abbreviation': 'HR',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'unearnedRuns',
#      'description': 'Unearned Runs',
#      'abbreviation': 'UER',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'runsBattedIn',
#      'description': 'Runs Batted In',
#      'abbreviation': 'RBI',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'earnedRuns',
#      'description': 'Earned Runs',
#      'abbreviation': 'ER',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterWalks',
#      'description': 'Walks',
#      'abbreviation': 'BB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSwings',
#      'description': 'Batter Swings',
#      'abbreviation': 'Swi',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikes',
#      'description': 'Batter Strikes',
#      'abbreviation': 'Str',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikesFoul',
#      'description': 'Batter Strikes (Foul)',
#      'abbreviation': 'StrF',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikesMiss',
#      'description': 'Batter Strikes (Miss)',
#      'abbreviation': 'StrM',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikesLooking',
#      'description': 'Batter Strikes (Looking)',
#      'abbreviation': 'StrL',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterGroundBalls',
#      'description': 'Batter Ground Balls',
#      'abbreviation': 'GroB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterFlyBalls',
#      'description': 'Batter Fly Balls',
#      'abbreviation': 'FlyB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterLineDrives',
#      'description': 'Batter Line Drives',
#      'abbreviation': 'LD',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batter4SeamFastballs',
#      'description': 'Batter 4-Seam Fastballs Faced',
#      'abbreviation': 'BFF',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSinkers',
#      'description': 'Batter Sinkers Faced',
#      'abbreviation': 'BFT',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterChangeups',
#      'description': 'Batter Changeups Faced',
#      'abbreviation': 'BCH',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batter2SeamFastballs',
#      'description': 'Batter 2-Seam Fastballs Faced',
#      'abbreviation': 'BFT',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'opponentsLeftOnBase',
#      'description': 'Opponents Left On Base',
#      'abbreviation': 'OLOB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSliders',
#      'description': 'Batter Sliders Faced',
#      'abbreviation': 'BSL',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterCurveballs',
#      'description': 'Batter Curveballs Faced',
#      'abbreviation': 'BCU',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'leftOnBase',
#      'description': 'Left On Base',
#      'abbreviation': 'LOB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikeouts',
#      'description': 'Strikeouts',
#      'abbreviation': 'SO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSplitters',
#      'description': 'Batter Splitters Faced',
#      'abbreviation': 'BFT',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterCutters',
#      'description': 'Batter Cutters Faced',
#      'abbreviation': 'BCU',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'stolenBases',
#      'description': 'Stolen Bases',
#      'abbreviation': 'SB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'caughtBaseSteals',
#      'description': 'Caught Stealing',
#      'abbreviation': 'CS',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStolenBasePct',
#      'description': 'Stolen Base Percentage',
#      'abbreviation': 'SB%',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'battingAvg',
#      'description': 'Batting Average',
#      'abbreviation': 'AVG',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterOnBasePct',
#      'description': 'On Base Percentage',
#      'abbreviation': 'OBP',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterSluggingPct',
#      'description': 'Slugging Percentage',
#      'abbreviation': 'SLG',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterOnBasePlusSluggingPct',
#      'description': 'On Base Plus Slugging Percentage',
#      'abbreviation': 'OPS',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterIntentionalWalks',
#      'description': 'Intentional Batting Walks',
#      'abbreviation': 'IBB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'hitByPitch',
#      'description': 'Hit By Pitch',
#      'abbreviation': 'HBP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSacrificeBunts',
#      'description': 'Sacrifice Bunts',
#      'abbreviation': 'SacB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSacrificeFlies',
#      'description': 'Sacrifice Flies',
#      'abbreviation': 'SacF',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'totalBases',
#      'description': 'Total Bases',
#      'abbreviation': 'TB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'extraBaseHits',
#      'description': 'Extra Base Hits',
#      'abbreviation': 'XBH',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterDoublePlays',
#      'description': 'Batted Double Plays',
#      'abbreviation': 'BDP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterTriplePlays',
#      'description': 'Batted Triple Plays',
#      'abbreviation': 'BTP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterTagOuts',
#      'description': 'Batted Tag Outs',
#      'abbreviation': 'BTO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterForceOuts',
#      'description': 'Batted Force Outs',
#      'abbreviation': 'BFO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterPutOuts',
#      'description': 'Batted Force Outs',
#      'abbreviation': 'BPO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterGroundOuts',
#      'description': 'Ground Outs',
#      'abbreviation': 'GO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterFlyOuts',
#      'description': 'Fly Outs',
#      'abbreviation': 'AO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterGroundOutToFlyOutRatio',
#      'description': 'Ground Out to Fly Out Ratio',
#      'abbreviation': 'GO/AO',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'pitchesFaced',
#      'description': 'Pitches Faced',
#      'abbreviation': 'NP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'plateAppearances',
#      'description': 'Plate Appearances',
#      'abbreviation': 'PA',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'opponentAtBats',
#      'description': 'Opponent At Bats',
#      'abbreviation': 'OppAB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'earnedRunAvg',
#      'description': 'Earned Run Average',
#      'abbreviation': 'ERA',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'inningsPitched',
#      'description': 'Innings Pitched',
#      'abbreviation': 'IP',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'hitsAllowed',
#      'description': 'Hits Allowed',
#      'abbreviation': 'HAll',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'secondBaseHitsAllowed',
#      'description': '2nd Base Hits Allowed',
#      'abbreviation': '2BAll',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'thirdBaseHitsAllowed',
#      'description': '3rd Base Hits Allowed',
#      'abbreviation': '3BAll',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'runsAllowed',
#      'description': 'Runs Allowed',
#      'abbreviation': 'R',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'earnedRunsAllowed',
#      'description': 'Earned Runs Allowed',
#      'abbreviation': 'ER',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'homerunsAllowed',
#      'description': 'Homeruns Allowed',
#      'abbreviation': 'HR',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherWalks',
#      'description': 'Walks',
#      'abbreviation': 'BB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSwings',
#      'description': 'Pitcher Swings',
#      'abbreviation': 'Swi',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikes',
#      'description': 'Pitcher Strikes',
#      'abbreviation': 'Str',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikesFoul',
#      'description': 'Pitcher Strikes (Foul)',
#      'abbreviation': 'StrF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikesMiss',
#      'description': 'Pitcher Strikes (Miss)',
#      'abbreviation': 'StrM',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikesLooking',
#      'description': 'Pitcher Strikes (Looking)',
#      'abbreviation': 'StrL',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherGroundBalls',
#      'description': 'Pitcher Ground Balls',
#      'abbreviation': 'GroB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherFlyBalls',
#      'description': 'Pitcher Fly Balls',
#      'abbreviation': 'FlyB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherLineDrives',
#      'description': 'Pitcher Line Drives',
#      'abbreviation': 'LD',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSinkers',
#      'description': 'Pitcher Sinkers Thrown',
#      'abbreviation': 'PFT',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherChangeups',
#      'description': 'Pitcher Changeups Thrown',
#      'abbreviation': 'PCH',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcher2SeamFastballs',
#      'description': 'Pitcher 2-Seam Fastballs Thrown',
#      'abbreviation': 'PFT',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSacrificeBunts',
#      'description': 'Pitcher Sacrifice Bunts',
#      'abbreviation': 'SacB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSliders',
#      'description': 'Pitcher Sliders Thrown',
#      'abbreviation': 'PSL',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherCurveballs',
#      'description': 'Pitcher Curveballs Thrown',
#      'abbreviation': 'PCU',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSplitters',
#      'description': 'Pitcher Splitters Thrown',
#      'abbreviation': 'PFT',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherCutters',
#      'description': 'Pitcher Cutters Thrown',
#      'abbreviation': 'PCU',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcher4SeamFastballs',
#      'description': 'Pitcher 4-Seam Fastballs Thrown',
#      'abbreviation': 'PFF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSacrificeFlies',
#      'description': 'Pitcher Sacrifice Flies',
#      'abbreviation': 'SacF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikeouts',
#      'description': 'Strikeouts',
#      'abbreviation': 'SO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitchingAvg',
#      'description': 'Pitching Average',
#      'abbreviation': 'AVG',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'walksAndHitsPerInningPitched',
#      'description': 'Walks And Hits Per Inning Pitched',
#      'abbreviation': 'WHIP',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'shutouts',
#      'description': 'Shutouts',
#      'abbreviation': 'SHO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'battersHit',
#      'description': 'Batters Hit',
#      'abbreviation': 'HB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherIntentionalWalks',
#      'description': 'Intentional Batters Walked',
#      'abbreviation': 'IBB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherGroundOuts',
#      'description': 'Ground Outs',
#      'abbreviation': 'GO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherFlyOuts',
#      'description': 'Fly Outs',
#      'abbreviation': 'AO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherWildPitches',
#      'description': 'Wild Pitches',
#      'abbreviation': 'WP',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'balks',
#      'description': 'Balks',
#      'abbreviation': 'BK',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStolenBasesAllowed',
#      'description': 'Stolen Bases Allowed',
#      'abbreviation': 'SB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherCaughtStealing',
#      'description': 'Batters Caught Stealing',
#      'abbreviation': 'CS',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pickoffAttempts',
#      'description': 'Pickoff Attempts',
#      'abbreviation': 'PKA',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pickoffs',
#      'description': 'Pickoffs',
#      'abbreviation': 'PK',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'totalBattersFaced',
#      'description': 'Total Batters Faced',
#      'abbreviation': 'TBF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitchesThrown',
#      'description': 'Pitches Thrown',
#      'abbreviation': 'NP',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherGroundOutToFlyOutRatio',
#      'description': 'Ground Out to Fly Out Ratio',
#      'abbreviation': 'GO/AO',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherOnBasePct',
#      'description': 'On Base Percentage',
#      'abbreviation': 'OBP',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSluggingPct',
#      'description': 'Slugging Percentage',
#      'abbreviation': 'SLG',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherOnBasePlusSluggingPct',
#      'description': 'On Base Plus Sluging Percentage',
#      'abbreviation': 'OPS',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'strikeoutsPer9Innings',
#      'description': 'Strikeouts per 9 Innings',
#      'abbreviation': 'K/9',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'walksAllowedPer9Innings',
#      'description': 'Walks per 9 Innings',
#      'abbreviation': 'BB/9',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'hitsAllowedPer9Innings',
#      'description': 'Hits Allowed per 9 Innings',
#      'abbreviation': 'H/9',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'strikeoutsToWalksRatio',
#      'description': 'Strikeouts to Walks Ratio',
#      'abbreviation': 'K/BB',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitchesPerInning',
#      'description': 'Pitches per Inning',
#      'abbreviation': 'P/IP',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'inningsPlayed',
#      'description': 'Innings Played',
#      'abbreviation': 'INN',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'totalChances',
#      'description': 'Total Chances',
#      'abbreviation': 'TC',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderForceOuts',
#      'description': 'Fielded Force Outs',
#      'abbreviation': 'FFO',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderTagOuts',
#      'description': 'Fielded Tag Outs',
#      'abbreviation': 'FTO',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderPutOuts',
#      'description': 'Fielded Putouts',
#      'abbreviation': 'FPO',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'assists',
#      'description': 'Assists',
#      'abbreviation': 'A',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'errors',
#      'description': 'Errors',
#      'abbreviation': 'E',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderDoublePlays',
#      'description': 'Fielded Double Plays',
#      'abbreviation': 'FDP',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderTriplePlays',
#      'description': 'Fielded Triple Plays',
#      'abbreviation': 'FTP',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderStolenBasesAllowed',
#      'description': 'Stolen Bases Allowed',
#      'abbreviation': 'SB',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderCaughtStealing',
#      'description': 'Batters Caught Stealing',
#      'abbreviation': 'CS',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderStolenBasePct',
#      'description': 'Stolen Base Percentage',
#      'abbreviation': 'SB%',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'passedBalls',
#      'description': 'Passed Balls',
#      'abbreviation': 'PB',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderWildPitches',
#      'description': 'Catching Wild Pitches',
#      'abbreviation': 'WP',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fieldingPct',
#      'description': 'Field Percentage',
#      'abbreviation': 'FPCT',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'defenceEfficiencyRatio',
#      'description': 'Defence Efficiency Ratio',
#      'abbreviation': 'DER',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'outsFaced',
#      'description': 'Outs Faced',
#      'abbreviation': 'OF',
#      'type': 'INTEGER'},
#     {'category': 'Standings',
#      'fullName': 'wins',
#      'description': 'Wins',
#      'abbreviation': 'W',
#      'type': 'INTEGER'},
#     {'category': 'Standings',
#      'fullName': 'losses',
#      'description': 'Losses',
#      'abbreviation': 'L',
#      'type': 'INTEGER'},
#     {'category': 'Standings',
#      'fullName': 'winPct',
#      'description': 'Win %',
#      'abbreviation': 'Win %',
#      'type': 'DECIMAL'},
#     {'category': 'Standings',
#      'fullName': 'gamesBack',
#      'description': 'Games Back',
#      'abbreviation': 'GB',
#      'type': 'DECIMAL'},
#     {'category': 'Standings',
#      'fullName': 'runsFor',
#      'description': 'Runs For',
#      'abbreviation': 'RF',
#      'type': 'INTEGER'},
#     {'category': 'Standings',
#      'fullName': 'runsAgainst',
#      'description': 'Runs Against',
#      'abbreviation': 'RA',
#      'type': 'INTEGER'},
#     {'category': 'Standings',
#      'fullName': 'runDifferential',
#      'description': 'Run Differential',
#      'abbreviation': 'RunDiff',
#      'type': 'INTEGER'}],
#    'supportedPlayerStats': [{'category': 'Batting',
#      'fullName': 'atBats',
#      'description': 'At Bats',
#      'abbreviation': 'AB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'runs',
#      'description': 'Runs',
#      'abbreviation': 'R',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'hits',
#      'description': 'Hits',
#      'abbreviation': 'H',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'secondBaseHits',
#      'description': '2nd Base Hits',
#      'abbreviation': '2B',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'thirdBaseHits',
#      'description': '3rd Base Hits',
#      'abbreviation': '3B',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'homeruns',
#      'description': 'Homeruns',
#      'abbreviation': 'HR',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'runsBattedIn',
#      'description': 'Runs Batted In',
#      'abbreviation': 'RBI',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'unearnedRuns',
#      'description': 'Unearned Runs',
#      'abbreviation': 'UER',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'earnedRuns',
#      'description': 'Earned Runs',
#      'abbreviation': 'ER',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterWalks',
#      'description': 'Walks',
#      'abbreviation': 'BB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSwings',
#      'description': 'Batter Swings',
#      'abbreviation': 'Swi',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikes',
#      'description': 'Batter Strikes',
#      'abbreviation': 'Str',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikesFoul',
#      'description': 'Batter Strikes (Foul)',
#      'abbreviation': 'StrF',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikesMiss',
#      'description': 'Batter Strikes (Miss)',
#      'abbreviation': 'StrM',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikesLooking',
#      'description': 'Batter Strikes (Looking)',
#      'abbreviation': 'StrL',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterGroundBalls',
#      'description': 'Batter Ground Balls',
#      'abbreviation': 'GroB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterFlyBalls',
#      'description': 'Batter Fly Balls',
#      'abbreviation': 'FlyB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterLineDrives',
#      'description': 'Batter Line Drives',
#      'abbreviation': 'LD',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterCurveballs',
#      'description': 'Batter Curveballs Faced',
#      'abbreviation': 'BCU',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'leftOnBase',
#      'description': 'Left On Base',
#      'abbreviation': 'LOB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSplitters',
#      'description': 'Batter Splitters Faced',
#      'abbreviation': 'BFS',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterCutters',
#      'description': 'Batter Cutters Faced',
#      'abbreviation': 'BFC',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batter4SeamFastballs',
#      'description': 'Batter 4-Seam Fastballs Faced',
#      'abbreviation': 'BFF',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSinkers',
#      'description': 'Batter Sinkers Faced',
#      'abbreviation': 'BSI',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterChangeups',
#      'description': 'Batter Changeups Faced',
#      'abbreviation': 'BCH',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batter2SeamFastballs',
#      'description': 'Batter 2-Seam Fastballs Faced',
#      'abbreviation': 'BFT',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStrikeouts',
#      'description': 'Strikeouts',
#      'abbreviation': 'SO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSliders',
#      'description': 'Batter Sliders Faced',
#      'abbreviation': 'BSL',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'stolenBases',
#      'description': 'Stolen Bases',
#      'abbreviation': 'SB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'caughtBaseSteals',
#      'description': 'Caught Stealing',
#      'abbreviation': 'CS',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterStolenBasePct',
#      'description': 'Stolen Base Percentage',
#      'abbreviation': 'SB%',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'battingAvg',
#      'description': 'Batting Average',
#      'abbreviation': 'AVG',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterOnBasePct',
#      'description': 'On Base Percentage',
#      'abbreviation': 'OBP',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterSluggingPct',
#      'description': 'Slugging Percentage',
#      'abbreviation': 'SLG',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterOnBasePlusSluggingPct',
#      'description': 'On Base Plus Slugging Percentage',
#      'abbreviation': 'OPS',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'batterIntentionalWalks',
#      'description': 'Intentional Batting Walks',
#      'abbreviation': 'IBB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'hitByPitch',
#      'description': 'Hit By Pitch',
#      'abbreviation': 'HBP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSacrificeBunts',
#      'description': 'Sacrifice Bunts',
#      'abbreviation': 'SAC',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterSacrificeFlies',
#      'description': 'Sacrifice Flies',
#      'abbreviation': 'SF',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'totalBases',
#      'description': 'Total Bases',
#      'abbreviation': 'TB',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'extraBaseHits',
#      'description': 'Extra Base Hits',
#      'abbreviation': 'XBH',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterDoublePlays',
#      'description': 'Batted Double Plays',
#      'abbreviation': 'BDP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterTriplePlays',
#      'description': 'Batted Triple Plays',
#      'abbreviation': 'BTP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterTagOuts',
#      'description': 'Batted Tag Outs',
#      'abbreviation': 'BTO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterForceOuts',
#      'description': 'Batted Forced Outs',
#      'abbreviation': 'BFO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterPutOuts',
#      'description': 'Batted Put Outs',
#      'abbreviation': 'BPO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterGroundOuts',
#      'description': 'Ground Outs',
#      'abbreviation': 'GO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterFlyOuts',
#      'description': 'Fly Outs',
#      'abbreviation': 'AO',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'batterGroundOutToFlyOutRatio',
#      'description': 'Ground Out to Fly Out Ratio',
#      'abbreviation': 'GO/AO',
#      'type': 'DECIMAL'},
#     {'category': 'Batting',
#      'fullName': 'pitchesFaced',
#      'description': 'Pitches Faced',
#      'abbreviation': 'NP',
#      'type': 'INTEGER'},
#     {'category': 'Batting',
#      'fullName': 'plateAppearances',
#      'description': 'Plate Appearances',
#      'abbreviation': 'PA',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'wins',
#      'description': 'Wins',
#      'abbreviation': 'W',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'losses',
#      'description': 'Losses',
#      'abbreviation': 'L',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'earnedRunAvg',
#      'description': 'Earned Run Average',
#      'abbreviation': 'ERA',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'saves',
#      'description': 'Saves',
#      'abbreviation': 'SV',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'saveOpportunities',
#      'description': 'Save Opportunities',
#      'abbreviation': 'SVO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'inningsPitched',
#      'description': 'Innings Pitched',
#      'abbreviation': 'IP',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'hitsAllowed',
#      'description': 'Hits Allowed',
#      'abbreviation': 'H',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'secondBaseHitsAllowed',
#      'description': '2nd Base Hits Allowed',
#      'abbreviation': '2B',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'thirdBaseHitsAllowed',
#      'description': '3rd Base Hits Allowed',
#      'abbreviation': '3B',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'runsAllowed',
#      'description': 'Runs Allowed',
#      'abbreviation': 'R',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'earnedRunsAllowed',
#      'description': 'Earned Runs Allowed',
#      'abbreviation': 'ER',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'homerunsAllowed',
#      'description': 'Homeruns Allowed',
#      'abbreviation': 'HR',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherWalks',
#      'description': 'Walks',
#      'abbreviation': 'BB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSwings',
#      'description': 'Pitcher Swings',
#      'abbreviation': 'Swi',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikes',
#      'description': 'Pitcher Strikes',
#      'abbreviation': 'Str',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikesFoul',
#      'description': 'Pitcher Strikes (Foul)',
#      'abbreviation': 'StrF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikesMiss',
#      'description': 'Pitcher Strikes (Miss)',
#      'abbreviation': 'StrM',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikesLooking',
#      'description': 'Pitcher Strikes (Looking)',
#      'abbreviation': 'StrL',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherGroundBalls',
#      'description': 'Pitcher Ground Balls',
#      'abbreviation': 'GroB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherFlyBalls',
#      'description': 'Pitcher Fly Balls',
#      'abbreviation': 'FlyB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherLineDrives',
#      'description': 'Pitcher Line Drives',
#      'abbreviation': 'LD',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcher2SeamFastballs',
#      'description': 'Pitcher 2-Seam Fastballs Thrown',
#      'abbreviation': 'PFT',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSliders',
#      'description': 'Pitcher Sliders Thrown',
#      'abbreviation': 'PSL',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherCurveballs',
#      'description': 'Pitcher Curveballs Thrown',
#      'abbreviation': 'PCU',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSplitters',
#      'description': 'Pitcher Splitters Thrown',
#      'abbreviation': 'PFS',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherCutters',
#      'description': 'Pitcher Cutters Thrown',
#      'abbreviation': 'PFC',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcher4SeamFastballs',
#      'description': 'Pitcher 4-Seam Fastballs Thrown',
#      'abbreviation': 'PFF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSacrificeBunts',
#      'description': 'Sacrifice Bunts',
#      'abbreviation': 'SAC',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSinkers',
#      'description': 'Pitcher Sinkers Thrown',
#      'abbreviation': 'PSI',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherChangeups',
#      'description': 'Pitcher Changeups Thrown',
#      'abbreviation': 'PCH',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSacrificeFlies',
#      'description': 'Sacrifice Flies',
#      'abbreviation': 'SF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStrikeouts',
#      'description': 'Strikeouts',
#      'abbreviation': 'SO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitchingAvg',
#      'description': 'Pitching Average',
#      'abbreviation': 'AVG',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'walksAndHitsPerInningPitched',
#      'description': 'Walks And Hits Per Inning Pitched',
#      'abbreviation': 'WHIP',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'completedGames',
#      'description': 'Completed Games',
#      'abbreviation': 'CG',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'shutouts',
#      'description': 'Shutouts',
#      'abbreviation': 'SHO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'battersHit',
#      'description': 'Batters Hit',
#      'abbreviation': 'HB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherIntentionalWalks',
#      'description': 'Intentional Batters Walked',
#      'abbreviation': 'IBB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'gamesFinished',
#      'description': 'Games Finished',
#      'abbreviation': 'GF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'holds',
#      'description': 'Holds',
#      'abbreviation': 'HLD',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherDoublePlays',
#      'description': 'Pitched Double Plays',
#      'abbreviation': 'PDP',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherTriplePlays',
#      'description': 'Pitched Triple Plays',
#      'abbreviation': 'PTP',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherGroundOuts',
#      'description': 'Ground Outs',
#      'abbreviation': 'GO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherFlyOuts',
#      'description': 'Fly Outs',
#      'abbreviation': 'AO',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherWildPitches',
#      'description': 'Wild Pitches',
#      'abbreviation': 'WP',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'balks',
#      'description': 'Balks',
#      'abbreviation': 'BK',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherStolenBasesAllowed',
#      'description': 'Stolen Bases Allowed',
#      'abbreviation': 'SB',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherCaughtStealing',
#      'description': 'Batters Caught Stealing',
#      'abbreviation': 'CS',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pickoffAttempts',
#      'description': 'Pickoff Attempts',
#      'abbreviation': 'PKA',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pickoffs',
#      'description': 'Pickoffs',
#      'abbreviation': 'PK',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'totalBattersFaced',
#      'description': 'Total Batters Faced',
#      'abbreviation': 'TBF',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'pitchesThrown',
#      'description': 'Pitches Thrown',
#      'abbreviation': 'NP',
#      'type': 'INTEGER'},
#     {'category': 'Pitching',
#      'fullName': 'winPct',
#      'description': 'Win Percentage',
#      'abbreviation': 'WPCT',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherGroundOutToFlyOutRatio',
#      'description': 'Ground Out to Fly Out Ratio',
#      'abbreviation': 'GO/AO',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherOnBasePct',
#      'description': 'On Base Percentage',
#      'abbreviation': 'OBP',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherSluggingPct',
#      'description': 'Slugging Percentage',
#      'abbreviation': 'SLG',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherOnBasePlusSluggingPct',
#      'description': 'On Base Plus Sluging Percentage',
#      'abbreviation': 'OPS',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'strikeoutsPer9Innings',
#      'description': 'Strikeouts per 9 Innings',
#      'abbreviation': 'K/9',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'walksAllowedPer9Innings',
#      'description': 'Walks per 9 Innings',
#      'abbreviation': 'BB/9',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'hitsAllowedPer9Innings',
#      'description': 'Hits Allowed per 9 Innings',
#      'abbreviation': 'H/9',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'strikeoutsToWalksRatio',
#      'description': 'Strikeouts to Walks Ratio',
#      'abbreviation': 'K/BB',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitchesPerInning',
#      'description': 'Pitches per Inning',
#      'abbreviation': 'P/IP',
#      'type': 'DECIMAL'},
#     {'category': 'Pitching',
#      'fullName': 'pitcherAtBats',
#      'description': 'At Bats Pitched',
#      'abbreviation': 'ABP',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'inningsPlayed',
#      'description': 'Innings Played',
#      'abbreviation': 'INN',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'totalChances',
#      'description': 'Total Chances',
#      'abbreviation': 'TC',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderTagOuts',
#      'description': 'Fielded TagOuts',
#      'abbreviation': 'FTO',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderForceOuts',
#      'description': 'Fielded ForceOuts',
#      'abbreviation': 'FFO',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderPutOuts',
#      'description': 'Fielded Putouts',
#      'abbreviation': 'FPO',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'assists',
#      'description': 'Assists',
#      'abbreviation': 'A',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'errors',
#      'description': 'Errors',
#      'abbreviation': 'E',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderDoublePlays',
#      'description': 'Fielded Double Plays',
#      'abbreviation': 'FDP',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderTriplePlays',
#      'description': 'Fielded Triple Plays',
#      'abbreviation': 'FTP',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderStolenBasesAllowed',
#      'description': 'Stolen Bases Allowed',
#      'abbreviation': 'SB',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderCaughtStealing',
#      'description': 'Batters Caught Stealing',
#      'abbreviation': 'CS',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderStolenBasePct',
#      'description': 'Stolen Base Percentage',
#      'abbreviation': 'SB%',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'passedBalls',
#      'description': 'Passed Balls',
#      'abbreviation': 'PB',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fielderWildPitches',
#      'description': 'Catching Wild Pitches',
#      'abbreviation': 'WP',
#      'type': 'INTEGER'},
#     {'category': 'Fielding',
#      'fullName': 'fieldingPct',
#      'description': 'Field Percentage',
#      'abbreviation': 'FPCT',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'rangeFactor',
#      'description': 'Range Factor',
#      'abbreviation': 'RF',
#      'type': 'DECIMAL'},
#     {'category': 'Fielding',
#      'fullName': 'outsFaced',
#      'description': 'Outs Faced',
#      'abbreviation': 'OF',
#      'type': 'INTEGER'},
#     {'category': 'Miscellaneous',
#      'fullName': 'gamesStarted',
#      'description': 'Games Started',
#      'abbreviation': 'GS',
#      'type': 'INTEGER'}],
#    'notes': None}]}

# %% [markdown]
# ## Get all the team name abbreviations

# %%
url='https://api.mysportsfeeds.com/v2.0/pull/mlb/2018-regular/team_stats_totals.json'

# %% [markdown]
# ### LIST OF TEAM ABBREVIATIONS
# mlb10theshow.wikia.com/wiki/Team_Abbreviations

# %% [markdown]
# Arizona Diamondbacks - ARI
# Atlanta Braves - ATL
# Baltimore Orioles - BAL
# Boston Red Sox - BOS
# Chicago Cubs - CHC
# Chicago White Sox - CWS
# Cincinnati Reds - CIN
# Cleveland Indians - CLE
# Colorado Rockies - COL
# Detroit Tigers - DET
# Florida Marlins - MIA
# Houston Astros - HOU
# Kansas City Royals - KC
# Los Angeles Angels of Anaheim - LAA
# Los Angeles Dodgers - LAD
# Milwaukee Brewers - MIL
# Minnesota Twins - MIN
# New York Mets - NYM
# New York Yankees - NYY
# Oakland Athletics - OAK
# Philadelphia Phillies - PHI
# Pittsburgh Pirates - PIT
# San Diego Padres - SD
# San Francisco Giants - SF
# Seattle Mariners - SEA
# St. Louis Cardinals - STL
# Tampa Bay Rays - TB
# Texas Rangers - TEX
# Toronto Blue Jays - TOR
# Washington Nationals - WAS

# %% [markdown]
# ## Object-Oriented Programming

# %%
teams=['ARI', 'ATL', 'BAL', 'BOS', 'CHC', 'CWS', 'CIN', 
'CLE', 'COL', 'DET', 'MIA', 'HOU', 'KC', 'LAA', 
'LAD', 'MIL', 'MIN', 'NYM', 'NYY', 'OAK', 'PHI', 
'PIT', 'SD', 'SF', 'SEA', 'STL', 'TB', 'TEX', 'TOR', 'WAS']

# %%
# Get team-level statistics for the 2018 MLB season

class Baseball:

    def __init__(self, team):      
        self.url='https://api.mysportsfeeds.com/v2.0/pull/mlb/2018-regular/team_stats_totals.json'
        self.team=team
        self.apikey_token=apikey_token # defined outside of the class for security reasons.
        self.errors=[]
        self.results={}
        if self.team in teams:
            try:
                response = requests.get(            
                    url=self.url,
                    params={
                        "team": self.team,    
                    },
                    headers={
                        "Authorization": "Basic " + base64.b64encode('{}:{}'.format(apikey_token,'MYSPORTSFEEDS').encode('utf-8')).decode('ascii')
                    }
                )
                self.response = response.json()
                self.name =     self.response['teamStatsTotals'][0]['team']['name']
                self.city =     self.response['teamStatsTotals'][0]['team']['city']
                self.ballpark = self.response['teamStatsTotals'][0]['team']['homeVenue']['name']
                self.win_pct =  self.response['teamStatsTotals'][0]['stats']['standings']['winPct']
                self.results['Name']=self.name
                self.results['City']=self.city
                self.results['Ballpark']=self.ballpark
                self.results['Win Pct']=self.win_pct
            except requests.exceptions.RequestException:
                self.errors.append('HTTP Request failed')
                print(self.errors[0])
        else:
            self.errors.append('Please select from the following team abbreviations: {}'.format(', '.join(teams)))
            print(self.errors[0])
    
    # Batting statistics
    def batting_stats(self, *args):
        option='batting'
        errors=[]
        stats_dict = self.results
        for arg in args:
            if arg not in list(self.response['teamStatsTotals'][0]['stats'][option].keys()):
                errors.append('Please request from the following statistics: {}'.format(
                    ', '.join(list(self.response['teamStatsTotals'][0]['stats'][option].keys()))))
                print(errors[0])
            else:
                statvalue = self.response['teamStatsTotals'][0]['stats'][option][arg]
                stats_dict[arg]=statvalue
        return stats_dict
                
    # Pitching statistics
    def pitching_stats(self, *args):
        option='pitching'
        errors=[]
        stats_dict = self.results
        for arg in args:
            if arg not in list(self.response['teamStatsTotals'][0]['stats'][option].keys()):
                errors.append('Please request from the following statistics: {}'.format(
                    ', '.join(list(self.response['teamStatsTotals'][0]['stats'][option].keys()))))
                print(errors[0])
            else:
                statvalue = self.response['teamStatsTotals'][0]['stats'][option][arg]
                stats_dict[arg]=statvalue
        return stats_dict
            
    # Fielding statistics
    def fielding_stats(self, *args):
        option='fielding'
        errors=[]
        stats_dict = self.results
        for arg in args:
            if arg not in list(self.response['teamStatsTotals'][0]['stats'][option].keys()):
                errors.append('Please request from the following statistics: {}'.format(
                    ', '.join(list(self.response['teamStatsTotals'][0]['stats'][option].keys()))))
                print(errors[0])
            else:
                statvalue = self.response['teamStatsTotals'][0]['stats'][option][arg]
                stats_dict[arg]=statvalue
        return stats_dict
    
    # Overall statistics
    def overall_stats(self, *args):
        option='standings'
        errors=[]
        stats_dict = self.results
        for arg in args:
            if arg not in list(self.response['teamStatsTotals'][0]['stats'][option].keys()):
                errors.append('Please request from the following statistics: {}'.format(
                    ', '.join(list(self.response['teamStatsTotals'][0]['stats'][option].keys()))))
                print(errors[0])
            else:
                statvalue = self.response['teamStatsTotals'][0]['stats'][option][arg]
                stats_dict[arg]=statvalue
        return stats_dict

# %%
bosox = Baseball(team='Boston')
# Out:
# Please select from the following team abbreviations: ARI, ATL, BAL, BOS, CHC, CWS, CIN, CLE, COL, DET, MIA, HOU, KC, LAA, LAD, MIL, MIN, NYM, NYY, OAK, PHI, PIT, SD, SF, SEA, STL, TB, TEX, TOR, WAS

# %%
bosox = Baseball(team='BOS')

# %%
bosox.name, bosox.city, bosox.ballpark, bosox.win_pct
# Out:
# ('Red Sox', 'Boston', 'Fenway Park', 0.667)

# %%
bosox.results
# Out:
# {'Name': 'Red Sox',
#  'City': 'Boston',
#  'Ballpark': 'Fenway Park',
#  'Win Pct': 0.667}

# %%
mets = Baseball(team='NYM')

# %%
mets.name, mets.city, mets.ballpark, mets.win_pct
# Out:
# ('Mets', 'New York', 'Citi Field', 0.475)

# %% [markdown]
# ## Washington Nationals

# %%
nats = Baseball(team='NATS')
# Out:
# Please select from the following team abbreviations: ARI, ATL, BAL, BOS, CHC, CWS, CIN, CLE, COL, DET, MIA, HOU, KC, LAA, LAD, MIL, MIN, NYM, NYY, OAK, PHI, PIT, SD, SF, SEA, STL, TB, TEX, TOR, WAS

# %%
nats = Baseball(team='WAS')

# %%
nats.name, nats.city, nats.ballpark, nats.win_pct
# Out:
# ('Nationals', 'Washington', 'Nationals Park', 0.506)

# %%
nats.url
# Out:
# 'https://api.mysportsfeeds.com/v2.0/pull/mlb/2018-regular/team_stats_totals.json'

# %%
nats.response.keys()
# Out:
# dict_keys(['lastUpdatedOn', 'teamStatsTotals', 'references'])

# %%
nats.response['teamStatsTotals'][0]['stats'].keys()
# Out:
# dict_keys(['gamesPlayed', 'batting', 'pitching', 'fielding', 'standings'])

# %%
nats.response['teamStatsTotals'][0]['stats']['standings']
# Out:
# {'wins': 82,
#  'losses': 80,
#  'winPct': 0.506,
#  'gamesBack': 0.0,
#  'runsFor': 767,
#  'runsAgainst': 673,
#  'runDifferential': 94}

# %%
nats.response['references']['teamStatReferences']
# Out:
# [{'category': 'Batting',
#   'fullName': 'atBats',
#   'description': 'At Bats',
#   'abbreviation': 'AB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'runs',
#   'description': 'Runs',
#   'abbreviation': 'R',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'hits',
#   'description': 'Hits',
#   'abbreviation': 'H',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'secondBaseHits',
#   'description': '2nd Base Hits',
#   'abbreviation': '2B',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'thirdBaseHits',
#   'description': '3rd Base Hits',
#   'abbreviation': '3B',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'homeruns',
#   'description': 'Homeruns',
#   'abbreviation': 'HR',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'runsBattedIn',
#   'description': 'Runs Batted In',
#   'abbreviation': 'RBI',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterWalks',
#   'description': 'Walks',
#   'abbreviation': 'BB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterSwings',
#   'description': 'Batter Swings',
#   'abbreviation': 'Swi',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterStrikes',
#   'description': 'Batter Strikes',
#   'abbreviation': 'Str',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterStrikesFoul',
#   'description': 'Batter Strikes (Foul)',
#   'abbreviation': 'StrF',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterStrikesMiss',
#   'description': 'Batter Strikes (Miss)',
#   'abbreviation': 'StrM',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterStrikesLooking',
#   'description': 'Batter Strikes (Looking)',
#   'abbreviation': 'StrL',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterGroundBalls',
#   'description': 'Batter Ground Balls',
#   'abbreviation': 'GroB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterFlyBalls',
#   'description': 'Batter Fly Balls',
#   'abbreviation': 'FlyB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterLineDrives',
#   'description': 'Batter Line Drives',
#   'abbreviation': 'LD',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterStrikeouts',
#   'description': 'Strikeouts',
#   'abbreviation': 'SO',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'stolenBases',
#   'description': 'Stolen Bases',
#   'abbreviation': 'SB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'caughtBaseSteals',
#   'description': 'Caught Stealing',
#   'abbreviation': 'CS',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterStolenBasePct',
#   'description': 'Stolen Base Percentage',
#   'abbreviation': 'SB%',
#   'type': 'DECIMAL'},
#  {'category': 'Batting',
#   'fullName': 'battingAvg',
#   'description': 'Batting Average',
#   'abbreviation': 'AVG',
#   'type': 'DECIMAL'},
#  {'category': 'Batting',
#   'fullName': 'batterOnBasePct',
#   'description': 'On Base Percentage',
#   'abbreviation': 'OBP',
#   'type': 'DECIMAL'},
#  {'category': 'Batting',
#   'fullName': 'batterSluggingPct',
#   'description': 'Slugging Percentage',
#   'abbreviation': 'SLG',
#   'type': 'DECIMAL'},
#  {'category': 'Batting',
#   'fullName': 'batterOnBasePlusSluggingPct',
#   'description': 'On Base Plus Slugging Percentage',
#   'abbreviation': 'OPS',
#   'type': 'DECIMAL'},
#  {'category': 'Batting',
#   'fullName': 'batterIntentionalWalks',
#   'description': 'Intentional Batting Walks',
#   'abbreviation': 'IBB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'hitByPitch',
#   'description': 'Hit By Pitch',
#   'abbreviation': 'HBP',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterSacrificeBunts',
#   'description': 'Sacrifice Bunts',
#   'abbreviation': 'SacB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterSacrificeFlies',
#   'description': 'Sacrifice Flies',
#   'abbreviation': 'SacF',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'totalBases',
#   'description': 'Total Bases',
#   'abbreviation': 'TB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'extraBaseHits',
#   'description': 'Extra Base Hits',
#   'abbreviation': 'XBH',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterDoublePlays',
#   'description': 'Batted Double Plays',
#   'abbreviation': 'BDP',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterGroundOuts',
#   'description': 'Ground Outs',
#   'abbreviation': 'GO',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterFlyOuts',
#   'description': 'Fly Outs',
#   'abbreviation': 'AO',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterGroundOutToFlyOutRatio',
#   'description': 'Ground Out to Fly Out Ratio',
#   'abbreviation': 'GO/AO',
#   'type': 'DECIMAL'},
#  {'category': 'Batting',
#   'fullName': 'pitchesFaced',
#   'description': 'Pitches Faced',
#   'abbreviation': 'NP',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'plateAppearances',
#   'description': 'Plate Appearances',
#   'abbreviation': 'PA',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'opponentAtBats',
#   'description': 'Opponent At Bats',
#   'abbreviation': 'OppAB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterTriplePlays',
#   'description': 'Batted Triple Plays',
#   'abbreviation': 'BTP',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterTagOuts',
#   'description': 'Batted Tag Outs',
#   'abbreviation': 'BTO',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterForceOuts',
#   'description': 'Batted Force Outs',
#   'abbreviation': 'BFO',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterPutOuts',
#   'description': 'Batted Force Outs',
#   'abbreviation': 'BPO',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batter2SeamFastballs',
#   'description': 'Batter 2-Seam Fastballs Faced',
#   'abbreviation': 'BFT',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batter4SeamFastballs',
#   'description': 'Batter 4-Seam Fastballs Faced',
#   'abbreviation': 'BFF',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterCurveballs',
#   'description': 'Batter Curveballs Faced',
#   'abbreviation': 'BCU',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterChangeups',
#   'description': 'Batter Changeups Faced',
#   'abbreviation': 'BCH',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterCutters',
#   'description': 'Batter Cutters Faced',
#   'abbreviation': 'BCU',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterSliders',
#   'description': 'Batter Sliders Faced',
#   'abbreviation': 'BSL',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterSinkers',
#   'description': 'Batter Sinkers Faced',
#   'abbreviation': 'BFT',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'batterSplitters',
#   'description': 'Batter Splitters Faced',
#   'abbreviation': 'BFT',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'earnedRuns',
#   'description': 'Earned Runs',
#   'abbreviation': 'ER',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'unearnedRuns',
#   'description': 'Unearned Runs',
#   'abbreviation': 'UER',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'leftOnBase',
#   'description': 'Left On Base',
#   'abbreviation': 'LOB',
#   'type': 'INTEGER'},
#  {'category': 'Batting',
#   'fullName': 'opponentsLeftOnBase',
#   'description': 'Opponents Left On Base',
#   'abbreviation': 'OLOB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'earnedRunAvg',
#   'description': 'Earned Run Average',
#   'abbreviation': 'ERA',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'inningsPitched',
#   'description': 'Innings Pitched',
#   'abbreviation': 'IP',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'hitsAllowed',
#   'description': 'Hits Allowed',
#   'abbreviation': 'HAll',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'secondBaseHitsAllowed',
#   'description': '2nd Base Hits Allowed',
#   'abbreviation': '2BAll',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'thirdBaseHitsAllowed',
#   'description': '3rd Base Hits Allowed',
#   'abbreviation': '3BAll',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'runsAllowed',
#   'description': 'Runs Allowed',
#   'abbreviation': 'R',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'earnedRunsAllowed',
#   'description': 'Earned Runs Allowed',
#   'abbreviation': 'ER',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'homerunsAllowed',
#   'description': 'Homeruns Allowed',
#   'abbreviation': 'HR',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherWalks',
#   'description': 'Walks',
#   'abbreviation': 'BB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherSwings',
#   'description': 'Pitcher Swings',
#   'abbreviation': 'Swi',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherStrikes',
#   'description': 'Pitcher Strikes',
#   'abbreviation': 'Str',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherStrikesFoul',
#   'description': 'Pitcher Strikes (Foul)',
#   'abbreviation': 'StrF',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherStrikesMiss',
#   'description': 'Pitcher Strikes (Miss)',
#   'abbreviation': 'StrM',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherStrikesLooking',
#   'description': 'Pitcher Strikes (Looking)',
#   'abbreviation': 'StrL',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherGroundBalls',
#   'description': 'Pitcher Ground Balls',
#   'abbreviation': 'GroB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherFlyBalls',
#   'description': 'Pitcher Fly Balls',
#   'abbreviation': 'FlyB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherLineDrives',
#   'description': 'Pitcher Line Drives',
#   'abbreviation': 'LD',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherSacrificeBunts',
#   'description': 'Pitcher Sacrifice Bunts',
#   'abbreviation': 'SacB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherSacrificeFlies',
#   'description': 'Pitcher Sacrifice Flies',
#   'abbreviation': 'SacF',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherStrikeouts',
#   'description': 'Strikeouts',
#   'abbreviation': 'SO',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitchingAvg',
#   'description': 'Pitching Average',
#   'abbreviation': 'AVG',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'walksAndHitsPerInningPitched',
#   'description': 'Walks And Hits Per Inning Pitched',
#   'abbreviation': 'WHIP',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'shutouts',
#   'description': 'Shutouts',
#   'abbreviation': 'SHO',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'battersHit',
#   'description': 'Batters Hit',
#   'abbreviation': 'HB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherIntentionalWalks',
#   'description': 'Intentional Batters Walked',
#   'abbreviation': 'IBB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherGroundOuts',
#   'description': 'Ground Outs',
#   'abbreviation': 'GO',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherFlyOuts',
#   'description': 'Fly Outs',
#   'abbreviation': 'AO',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherWildPitches',
#   'description': 'Wild Pitches',
#   'abbreviation': 'WP',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'balks',
#   'description': 'Balks',
#   'abbreviation': 'BK',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherStolenBasesAllowed',
#   'description': 'Stolen Bases Allowed',
#   'abbreviation': 'SB',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherCaughtStealing',
#   'description': 'Batters Caught Stealing',
#   'abbreviation': 'CS',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pickoffs',
#   'description': 'Pickoffs',
#   'abbreviation': 'PK',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'totalBattersFaced',
#   'description': 'Total Batters Faced',
#   'abbreviation': 'TBF',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitchesThrown',
#   'description': 'Pitches Thrown',
#   'abbreviation': 'NP',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherGroundOutToFlyOutRatio',
#   'description': 'Ground Out to Fly Out Ratio',
#   'abbreviation': 'GO/AO',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherOnBasePct',
#   'description': 'On Base Percentage',
#   'abbreviation': 'OBP',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherSluggingPct',
#   'description': 'Slugging Percentage',
#   'abbreviation': 'SLG',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherOnBasePlusSluggingPct',
#   'description': 'On Base Plus Sluging Percentage',
#   'abbreviation': 'OPS',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'strikeoutsPer9Innings',
#   'description': 'Strikeouts per 9 Innings',
#   'abbreviation': 'K/9',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'walksAllowedPer9Innings',
#   'description': 'Walks per 9 Innings',
#   'abbreviation': 'BB/9',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'hitsAllowedPer9Innings',
#   'description': 'Hits Allowed per 9 Innings',
#   'abbreviation': 'H/9',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'strikeoutsToWalksRatio',
#   'description': 'Strikeouts to Walks Ratio',
#   'abbreviation': 'K/BB',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'pitchesPerInning',
#   'description': 'Pitches per Inning',
#   'abbreviation': 'P/IP',
#   'type': 'DECIMAL'},
#  {'category': 'Pitching',
#   'fullName': 'pickoffAttempts',
#   'description': 'Pickoff Attempts',
#   'abbreviation': 'PKA',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcher2SeamFastballs',
#   'description': 'Pitcher 2-Seam Fastballs Thrown',
#   'abbreviation': 'PFT',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcher4SeamFastballs',
#   'description': 'Pitcher 4-Seam Fastballs Thrown',
#   'abbreviation': 'PFF',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherCurveballs',
#   'description': 'Pitcher Curveballs Thrown',
#   'abbreviation': 'PCU',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherChangeups',
#   'description': 'Pitcher Changeups Thrown',
#   'abbreviation': 'PCH',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherCutters',
#   'description': 'Pitcher Cutters Thrown',
#   'abbreviation': 'PCU',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherSliders',
#   'description': 'Pitcher Sliders Thrown',
#   'abbreviation': 'PSL',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherSinkers',
#   'description': 'Pitcher Sinkers Thrown',
#   'abbreviation': 'PFT',
#   'type': 'INTEGER'},
#  {'category': 'Pitching',
#   'fullName': 'pitcherSplitters',
#   'description': 'Pitcher Splitters Thrown',
#   'abbreviation': 'PFT',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'inningsPlayed',
#   'description': 'Innings Played',
#   'abbreviation': 'INN',
#   'type': 'DECIMAL'},
#  {'category': 'Fielding',
#   'fullName': 'totalChances',
#   'description': 'Total Chances',
#   'abbreviation': 'TC',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderPutOuts',
#   'description': 'Fielded Putouts',
#   'abbreviation': 'FPO',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'assists',
#   'description': 'Assists',
#   'abbreviation': 'A',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'errors',
#   'description': 'Errors',
#   'abbreviation': 'E',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderDoublePlays',
#   'description': 'Fielded Double Plays',
#   'abbreviation': 'FDP',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderStolenBasesAllowed',
#   'description': 'Stolen Bases Allowed',
#   'abbreviation': 'SB',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderCaughtStealing',
#   'description': 'Batters Caught Stealing',
#   'abbreviation': 'CS',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderStolenBasePct',
#   'description': 'Stolen Base Percentage',
#   'abbreviation': 'SB%',
#   'type': 'DECIMAL'},
#  {'category': 'Fielding',
#   'fullName': 'passedBalls',
#   'description': 'Passed Balls',
#   'abbreviation': 'PB',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderWildPitches',
#   'description': 'Catching Wild Pitches',
#   'abbreviation': 'WP',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fieldingPct',
#   'description': 'Field Percentage',
#   'abbreviation': 'FPCT',
#   'type': 'DECIMAL'},
#  {'category': 'Fielding',
#   'fullName': 'defenceEfficiencyRatio',
#   'description': 'Defence Efficiency Ratio',
#   'abbreviation': 'DER',
#   'type': 'DECIMAL'},
#  {'category': 'Fielding',
#   'fullName': 'fielderTriplePlays',
#   'description': 'Fielded Triple Plays',
#   'abbreviation': 'FTP',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderTagOuts',
#   'description': 'Fielded Tag Outs',
#   'abbreviation': 'FTO',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'fielderForceOuts',
#   'description': 'Fielded Force Outs',
#   'abbreviation': 'FFO',
#   'type': 'INTEGER'},
#  {'category': 'Fielding',
#   'fullName': 'outsFaced',
#   'description': 'Outs Faced',
#   'abbreviation': 'OF',
#   'type': 'INTEGER'},
#  {'category': 'Standings',
#   'fullName': 'wins',
#   'description': 'Wins',
#   'abbreviation': 'W',
#   'type': 'INTEGER'},
#  {'category': 'Standings',
#   'fullName': 'losses',
#   'description': 'Losses',
#   'abbreviation': 'L',
#   'type': 'INTEGER'},
#  {'category': 'Standings',
#   'fullName': 'winPct',
#   'description': 'Win %',
#   'abbreviation': 'Win %',
#   'type': 'DECIMAL'},
#  {'category': 'Standings',
#   'fullName': 'gamesBack',
#   'description': 'Games Back',
#   'abbreviation': 'GB',
#   'type': 'DECIMAL'},
#  {'category': 'Standings',
#   'fullName': 'runsFor',
#   'description': 'Runs For',
#   'abbreviation': 'RF',
#   'type': 'INTEGER'},
#  {'category': 'Standings',
#   'fullName': 'runsAgainst',
#   'description': 'Runs Against',
#   'abbreviation': 'RA',
#   'type': 'INTEGER'},
#  {'category': 'Standings',
#   'fullName': 'runDifferential',
#   'description': 'Run Differential',
#   'abbreviation': 'RunDiff',
#   'type': 'INTEGER'}]

# %%
nats.batting_stats('atBats', 'runs', 'hits')
# Out:
# {'atBats': 5450,
#  'Name': 'Nationals',
#  'City': 'Washington',
#  'Ballpark': 'Nationals Park',
#  'Win Pct': 0.506,
#  'runs': 767,
#  'hits': 1390}

# %%
nats.pitching_stats('pitcherCutters', 'pitcherSliders', 'pitcherSinkers')
# Out:
# {'pitcherCutters': 1242,
#  'Name': 'Nationals',
#  'City': 'Washington',
#  'Ballpark': 'Nationals Park',
#  'Win Pct': 0.506,
#  'pitcherSliders': 2968,
#  'pitcherSinkers': 2144}

# %%
nats.fielding_stats('fielderWildPitches', 'fielderTriplePlays', 'fielderStolenBasesAllowed')
# Out:
# {'fielderWildPitches': 41,
#  'Name': 'Nationals',
#  'City': 'Washington',
#  'Ballpark': 'Nationals Park',
#  'Win Pct': 0.506,
#  'fielderTriplePlays': 0,
#  'fielderStolenBasesAllowed': 78}

# %%
nats.overall_stats('runsFor', 'runsAgainst', 'runDifferential')
# Out:
# {'runsFor': 767,
#  'Name': 'Nationals',
#  'City': 'Washington',
#  'Ballpark': 'Nationals Park',
#  'Win Pct': 0.506,
#  'runsAgainst': 673,
#  'runDifferential': 94}

# %%
nats.batting_stats('some other stat')
# Out:
# Please request from the following statistics: atBats, runs, hits, secondBaseHits, thirdBaseHits, homeruns, runsBattedIn, earnedRuns, unearnedRuns, batterWalks, batterSwings, batterStrikes, batterStrikesFoul, batterStrikesMiss, batterStrikesLooking, batterGroundBalls, batterFlyBalls, batterLineDrives, batterStrikeouts, batter2SeamFastballs, batter4SeamFastballs, batterCurveballs, batterChangeups, batterCutters, batterSliders, batterSinkers, batterSplitters, leftOnBase, opponentsLeftOnBase, stolenBases, caughtBaseSteals, batterStolenBasePct, battingAvg, batterOnBasePct, batterSluggingPct, batterOnBasePlusSluggingPct, batterIntentionalWalks, hitByPitch, batterSacrificeBunts, batterSacrificeFlies, totalBases, extraBaseHits, batterDoublePlays, batterTriplePlays, batterTagOuts, batterForceOuts, batterPutOuts, batterGroundOuts, batterFlyOuts, batterGroundOutToFlyOutRatio, pitchesFaced, plateAppearances, opponentAtBats
# {}

# %%
nats.fielding_stats('some other stat')
# Out:
# Please request from the following statistics: inningsPlayed, totalChances, fielderTagOuts, fielderForceOuts, fielderPutOuts, assists, errors, fielderDoublePlays, fielderTriplePlays, fielderStolenBasesAllowed, fielderCaughtStealing, fielderStolenBasePct, passedBalls, fielderWildPitches, fieldingPct, defenceEfficiencyRatio, outsFaced
# {}

# %%
nats.pitching_stats('some other stat')
# Out:
# Please request from the following statistics: earnedRunAvg, inningsPitched, hitsAllowed, secondBaseHitsAllowed, thirdBaseHitsAllowed, runsAllowed, earnedRunsAllowed, homerunsAllowed, pitcherWalks, pitcherSwings, pitcherStrikes, pitcherStrikesFoul, pitcherStrikesMiss, pitcherStrikesLooking, pitcherGroundBalls, pitcherFlyBalls, pitcherLineDrives, pitcherSacrificeBunts, pitcher2SeamFastballs, pitcher4SeamFastballs, pitcherCurveballs, pitcherChangeups, pitcherCutters, pitcherSliders, pitcherSinkers, pitcherSplitters, pitcherSacrificeFlies, pitcherStrikeouts, pitchingAvg, walksAndHitsPerInningPitched, shutouts, battersHit, pitcherIntentionalWalks, pitcherGroundOuts, pitcherFlyOuts, pitcherWildPitches, balks, pitcherStolenBasesAllowed, pitcherCaughtStealing, pickoffs, pickoffAttempts, totalBattersFaced, pitchesThrown, pitcherGroundOutToFlyOutRatio, pitcherOnBasePct, pitcherSluggingPct, pitcherOnBasePlusSluggingPct, strikeoutsPer9Innings, walksAllowedPer9Innings, hitsAllowedPer9Innings, strikeoutsToWalksRatio, pitchesPerInning
# {}

# %%
nats.overall_stats('any other stat')
# Out:
# Please request from the following statistics: wins, losses, winPct, gamesBack, runsFor, runsAgainst, runDifferential
# {}
